# %%
#| hide
from fast_melbo.core import *

# %% [markdown]
# # fast_melbo
#
# > Optimising unsupervised steering vector (a.k.a MELBO) training

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install fast_melbo in Development mode

# %% [markdown]
# ```sh
# # make sure fast_melbo package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to fast_melbo
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/z3research/fast_melbo.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c z3research fast_melbo
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install fast_melbo
# ```
#
#
# [repo]: https://github.com/z3research/fast_melbo
# [docs]: https://z3research.github.io/fast_melbo/
# [pypi]: https://pypi.org/project/fast_melbo/
# [conda]: https://anaconda.org/z3research/fast_melbo

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/z3research/fast_melbo
# [docs]: https://z3research.github.io/fast_melbo/
# [pypi]: https://pypi.org/project/fast_melbo/
# [conda]: https://anaconda.org/z3research/fast_melbo

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
